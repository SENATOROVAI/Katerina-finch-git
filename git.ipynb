# %% [markdown]
# pip install --user cookiecutter

# %% [markdown]
# python -m cookiecutter
# Команда загружает шаблон на https://
# github.com/asweigart/cookiecutter-basicpythonproject.

# %% [markdown]
# gh - сокращение для https://github.com/ в аргументе командной строки

# %% [markdown]
# git --version

# %% [markdown]
# git config --global user.name "Ekaterina Zyrianova"
# git config --global user.email finch976@gmail.com
# git config --list
# задать ваше имя и адрес электронной почты, чтобы
# в ваши коммиты включалась информация об авторе

# %% [markdown]
# git init или git clone - создание репозитория
# git add <имя_файла> - добавление файлов в репозиторий
# git commit -am "<сообщение, описывающее содержание коммита>"
# - сохранение файла

# %% [markdown]
# git help <команда> - справка по командам

# %% [markdown]
# git status для просмотра текущего статуса репозитория и
# состояния его файлов

# %% [markdown]
# git commit -am command для индексирования
# и закрепления измененных файлов

# %% [markdown]
# C:\Users\Al>md wizcoin
# C:\Users\Al>cd wizcoin
# C:\Users\Al\wizcoin>git init

# %% [markdown]
# git status
#  watch
